# %% [markdown]
# # Access the analysis ready satellite sea surface temperature data

# %% [markdown]
# This notebook provides an example of how to open the satellite-sea-surface-temperature Zarr store using xarray.
# You will need to insert your CDS API key where indicated in the following code cell (available on [your profile page](https://cds.climate.copernicus.eu/profile)).
# For more information on using the Data Store Analysis Ready Datasets, please see the [user documentation pages](https://cds.climate.copernicus.eu/datasets/how-to-use-the-dss-arco-dataset).

# %%
import os
cdsapi_key = "<INSERT-CDS-API-KEY-HERE>"

# The following attempts to find the CDSAPI key in your environment.
if cdsapi_key == "<INSERT-CDS-API-KEY-HERE>":
    cdsapi_key = None
if cdsapi_key is None:
    cdsapi_key = os.getenv("CDSAPI_KEY")
if cdsapi_key is None and os.path.exists(os.path.expanduser("~/.cdsapirc")):
    with open(os.path.expanduser("~/.cdsapirc"), "r") as f:
        for line in f:
            if line.startswith("key:"):
                cdsapi_key = line.split(":")[1].strip()
                break
if cdsapi_key is None:
    raise ValueError("CDSAPI key not found. Please set the CDSAPI_KEY environment variable or create a ~/.cdsapirc file.")

# %% [markdown]
# ## Plug and play access
#
# The code below provides a simple plug and play example of how to use the Zarr Store for light-weight access.

# %%
import xarray as xr

# Geo-chunked combined product data (optimised for time-series at a single location)
geochunked_url = "https://arco.datastores.ecmwf.int/cadl-arco-geo-052/arco/satellite_sea_surface_temperature/combined/geoChunked.zarr"

# Time-chunked combined product data (optimised for map at a single time step)
timechunked_url = "https://arco.datastores.ecmwf.int/cadl-arco-time-052/arco/satellite_sea_surface_temperature/combined/timeChunked.zarr"


# Open the zarr store with xarray, users must insert their API key where indicated.
ds = xr.open_zarr(
    timechunked_url,
    consolidated=True,
     storage_options = {
        "headers": {"Authorization": f"Bearer {cdsapi_key}"}
    }
)
 
# Inspect the variables
ds
# Out:
# <xarray.Dataset> Size: 12TB
# Dimensions:                   (time: 16071, latitude: 3600, longitude: 7200)
# Coordinates:
#   * time                      (time) datetime64[ns] 129kB 1980-01-01 ... 2023...
#   * latitude                  (latitude) float32 14kB -89.97 -89.93 ... 89.97
#   * longitude                 (longitude) float32 29kB -180.0 -179.9 ... 180.0
# Data variables:
#     sea_ice_fraction          (time, latitude, longitude) float64 3TB dask.array<chunksize=(1, 1024, 1024), meta=np.ndarray>
#     analysed_sst              (time, latitude, longitude) float64 3TB dask.array<chunksize=(1, 1024, 1024), meta=np.ndarray>
#     analysed_sst_uncertainty  (time, latitude, longitude) float64 3TB dask.array<chunksize=(1, 1024, 1024), meta=np.ndarray>
#     mask                      (time, latitude, longitude) float32 2TB dask.array<chunksize=(1, 1024, 1024), meta=np.ndarray>

# %% [markdown]
# Plot a map of analysed sea surface temperature using earthkit-plots.

# %%
from earthkit import plots as ekp

# Select a single time step to plot
plot_data = ds["analysed_sst"].sel(time="2020-01-01", method="nearest")

chart = ekp.Map()

chart.grid_cells(plot_data)

chart.coastlines()
chart.gridlines()

chart.title("Analysed Sea Surface Temperature")

chart.show()

# %% [markdown]
# ## Advanced usage
#
# If your workflow requires access to larger amounts of data, it is recommended that you include a retry mechanism.
# This is not provided in the current default zarr engine for xarray, instead we can define a custom "`store`" which is
# used when connecting to the remote zarr data.

# %%
# !pip install -q obstore
import xarray as xr
from obstore.store import HTTPStore
from zarr.storage import ObjectStore

# Geo-chunked combined product data (optimised for time-series at a single location)
geochunked_url = "https://arco.datastores.ecmwf.int/cadl-arco-geo-052/arco/satellite_sea_surface_temperature/combined/geoChunked.zarr"

# Time-chunked combined product data (optimised for map at a single time step)
timechunked_url = "https://arco.datastores.ecmwf.int/cadl-arco-time-052/arco/satellite_sea_surface_temperature/combined/timeChunked.zarr"


# Use obstore's HTTPStore to create a store with retry configuration,
# and then wrap it in a zarr ObjectStore to read with xarray.
# See https://github.com/developmentseed/obstore/blob/main/obstore/python/obstore/_store/_retry.pyi
# for more details on the retry configuration options.
http_store = HTTPStore(
    geochunked_url,
    client_options={
        "default_headers": {"Authorization": f"Bearer {cdsapi_key}"},
    },
)
store = ObjectStore(http_store, read_only=True)
ds = xr.open_zarr(store)
ds
# Out:
# <xarray.Dataset> Size: 12TB
# Dimensions:                   (time: 16071, latitude: 3600, longitude: 7200)
# Coordinates:
#   * time                      (time) datetime64[ns] 129kB 1980-01-01 ... 2023...
#   * latitude                  (latitude) float32 14kB -89.97 -89.93 ... 89.97
#   * longitude                 (longitude) float32 29kB -180.0 -179.9 ... 180.0
# Data variables:
#     sea_ice_fraction          (time, latitude, longitude) float64 3TB dask.array<chunksize=(528, 32, 64), meta=np.ndarray>
#     analysed_sst              (time, latitude, longitude) float64 3TB dask.array<chunksize=(528, 32, 64), meta=np.ndarray>
#     analysed_sst_uncertainty  (time, latitude, longitude) float64 3TB dask.array<chunksize=(528, 32, 64), meta=np.ndarray>
#     mask                      (time, latitude, longitude) float32 2TB dask.array<chunksize=(528, 32, 64), meta=np.ndarray>

# %% [markdown]
# The result is the same as the previous example, this just provides a more robust connection, preventing your
# workflow crashing due to temporary network issues.
